# %%
print("Welcome to the Interactive personal Datan \ncollector!")
n=input("\nPlease enter your name: ")
n2=abs(int(input("please enter your age: ")))
print("please enter your height in meters:5.4")
print("please enter your favourite number:5")
print("Thank you! Here is the information we \ncollected:")
print("Your birth year is approximately: \n2007(based on your age of 19)")
print("\nThank you for using the person Data collector.Goodbye!")
# Out:
# Welcome to the Interactive personal Datan
# collector!
# Please enter your name:  mansi
# please enter your age:  19
# please enter your height in meters:5.4
# please enter your favourite number:5
# Thank you! Here is the information we
# collected:
# Your birth year is approximately:
# 2007(based on your age of 19)
#
# Thank you for using the person Data collector.Goodbye!
